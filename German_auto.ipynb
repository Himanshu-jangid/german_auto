# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("German_auto.csv")

# %%
df
# Out:
#           Brand     Model  Year  Mileage Fuel Type  \
# 0          Audi        Q7  2006   260886    Diesel
# 1          Opel     Corsa  2015    72505    Hybrid
# 2      Mercedes   C-Class  2007   125356  Electric
# 3    Volkswagen      Polo  2009   130867  Electric
# 4          Opel     Astra  2022    57482  Electric
# ..          ...       ...   ...      ...       ...
# 495  Volkswagen    Tiguan  2022   116092    Hybrid
# 496    Mercedes       GLA  2018   107863  Electric
# 497        Audi        Q7  2022   236821  Electric
# 498     Porsche     Macan  2014    81406    Petrol
# 499     Porsche  Panamera  2018   276428    Petrol
#
#      Fuel Consumption (L/100km)  Horsepower (HP) Transmission    Price   \
# 0                           9.5              213    Automatic  12063.27
# 1                           6.5              335    Automatic  33890.58
# 2                           9.9              445    Automatic  92639.12
# ...

# %%
df.head()
# Out:
#         Brand    Model  Year  Mileage Fuel Type  Fuel Consumption (L/100km)  \
# 0        Audi       Q7  2006   260886    Diesel                         9.5
# 1        Opel    Corsa  2015    72505    Hybrid                         6.5
# 2    Mercedes  C-Class  2007   125356  Electric                         9.9
# 3  Volkswagen     Polo  2009   130867  Electric                         4.1
# 4        Opel    Astra  2022    57482  Electric                         5.2
#
#    Horsepower (HP) Transmission    Price      City
# 0              213    Automatic  12063.27  Cologne
# 1              335    Automatic  33890.58   Berlin
# 2              445    Automatic  92639.12   Berlin
# 3              165    Automatic  88003.50   Munich
# 4              145       Manual  26028.97  Hamburg

# %%
df["Horsepower (HP)"].dtype
# Out:
# dtype('int64')

# %%
df["Horsepower (HP)"].max()
# Out:
# 500

# %%
df["Horsepower (HP)"].min()
# Out:
# 70

# %%
df["Fuel Consumption (L/100km)"].dtype
# Out:
# dtype('float64')

# %%
df.describe()
# Out:
#               Year        Mileage  Fuel Consumption (L/100km)  \
# count   500.000000     500.000000                  500.000000
# mean   2014.302000  158885.270000                    7.630800
# std       5.504125   85604.122684                    2.654805
# min    2005.000000    5667.000000                    3.000000
# 25%    2009.750000   85787.250000                    5.300000
# 50%    2014.000000  160433.500000                    7.900000
# 75%    2019.000000  234079.750000                   10.000000
# max    2023.000000  299573.000000                   12.000000
#
#        Horsepower (HP)        Price
# count       500.000000    500.000000
# mean        281.112000  51064.288940
# std         121.169251  28652.646997
# min          70.000000   5209.730000
# 25%         175.000000  24478.057500
# 50%         279.500000  52892.525000
# 75%         385.000000  75037.670000
# max         500.000000  99981.480000

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
cars = {"Mileage":[10, 12, 13, 14, 5, 6],
          "Price": ["1000000", "3000000", "2500000", "3500000", "4500000", "5000000"],
          "sales":[1000, 200, 150, 400, 50, 60],
          "HorsePower":["120", "150", "170", "200", "550", "650"]
          }

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.DataFrame(cars)
x = df["Price"]
y = df["Mileage"]
plt.bar(x,y, label="Price", color="Red")
plt.xlabel("Price")
plt.ylabel("Mileage")
plt.title("German_Auto")
plt.legend()
plt.show()

# %%
Mileage = [22,45,30,59,58,56,57,45,43,43,43,50,40,34,33,25,19]
interval = [0,10,20,30,40,50,60]

# %%
plt.hist(Mileage, interval, histtype="bar", rwidth=0.8, color='Red')
# Out:
# (array([0., 1., 2., 3., 6., 5.]),
#  array([ 0., 10., 20., 30., 40., 50., 60.]),
#  <BarContainer object of 6 artists>)

# %%
import matplotlib.pyplot as plt

Mileage= [22,45,30,59,58,56,57,45,43,43,43,50,40,34,33,25,19]
interval = [0,10,20,30,40,50,60]
plt.hist(Mileage, interval, histtype="bar", rwidth=0.8, color='Grey')
plt.xlabel("Price")
plt.ylabel("Mileage")
plt.title("German_Auto")
plt.legend()
plt.show()
# Out:
# C:\Users\himan\AppData\Local\Temp\ipykernel_18076\2078086692.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import matplotlib.pyplot as plt

# Data
slices = [50, 14, 24, 16]
Specification = ["Price", "Mileage", "Sales", "HorsePower"]
color = ["Green", "Grey", "Black", "Gold"]

plt.figure(figsize=(8, 6)) 
plt.pie(slices, labels=Specification, colors=color,
        startangle=90, explode=(0, 0.2, 0, 0),
        shadow=True, autopct="%.1f%%")

plt.title("German Auto Specifications")
plt.legend(Specification, title="Specifications", loc="upper right")

plt.show()

# %%
import matplotlib.pyplot as plt
years = ["2015", "2016", "2017", "2018", "2019", "2020", "2021"]
profits = [9, 1, 10, 8, 2, 5, 6]
plt.figure(figsize=(10, 6))  
plt.plot(years, profits, marker='o', color='blue', linestyle='-', linewidth=2)
plt.title("Company Profits Year-wise", fontsize=16)
plt.xlabel("Year", fontsize=14)
plt.ylabel("Profit (in Rs)", fontsize=14)
plt.tight_layout()
plt.show()
